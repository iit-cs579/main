# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
#
#
# <center>
# <b><font size="+3">CS579: Online Social Network Analysis </font></b>
# <br>
# **Lecture 01**
# *[Dr. Aron Culotta](http://cs.iit.edu/~culotta)*
# *[Illinois Institute of Technology](http://iit.edu)*
#
# </center>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# What is an **online social network?**
#
# <br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 50px;">
# <img width=50% src="images/fb_logo.png"/>
# </span>
#
# - 1.7B users
# - 70B pieces of content shared / day
# - 150K messages sent / minute
#
# Sources: [\[1\]](http://www.statisticbrain.com/facebook-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/twitter_logo2.png"/>
# </span>
#
# <br>
#
# - 700M users
# - 58M tweets / day
# - >200B total tweets
#
# Sources: [\[1\]](http://www.statisticbrain.com/twitter-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/instagram.png"/>
# </span>
# <br>
# - 500M active users
# - 40B shared photos
# - 95M photos / day
# - 100 comments / second
#
# Sources: [\[1\]](http://www.huffingtonpost.com/brian-honigman/100-fascinating-social-me_b_2185281.html) [\[2\]](https://blog.hootsuite.com/instagram-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/sina-weibo.png"/>
# </span>
# <br>
#
# - 360M active users
# - 2B daily video views
# - 100M posts / day
#
# Sources: [\[1\]](http://expandedramblings.com/index.php/weibo-user-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### A large portion of the world's conversations are conducted in public.

# %% [markdown]
# ### Is there anything useful in this chatter?

# %% [markdown]
# ![brand](images/brand.png)
#
# [Radian6](http://www.salesforcemarketingcloud.com/blog/2012/08/social-media-insights-peekanalytics-at-work/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![flu](images/flu.png)
#
# - [Paul & Dredze \[2011\]](http://www.cs.jhu.edu/~mdredze/publications/twitter_health_icwsm_11.pdf)
# - [Culotta \[2010\]](http://cs.iit.edu/~culotta/pubs/culotta10towards.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![gallup](images/gallup.png)
#
# [O'Connor et al. \[2010\]](http://www.cs.cmu.edu/~nasmith/papers/oconnor+balasubramanyan+routledge+smith.icwsm10.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![djia](images/djia.png)
#
# [Bollen et al. \[2010\]](http://arxiv.org/pdf/1010.3003v1.pdf)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![crisis](images/crisis.png)
#
# [Rogstadius et al. \[2013\]](http://ufn.virtues.fi/~jakob/twitter/about.php)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![earthquake](images/earthquake.png)
#
# [Kumar et al. \[2011\]](http://www.public.asu.edu/~mabbasi2/papers/kumar2011tweettracker.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# **How does this** ![tweets](images/tweets.png) **become useful?**
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ###  Algorithms + Data = The Microscope of the 21st Century
#
# <table style="border: none;border-collapse: collapse;" border="0" >
# <tr><td><img src="images/tree.png" width=80%></td>
# <td>
# <ul>
# <li>Much as the microscope allowed scientists to see things they previously couldn't, now computer science provides new windows into human behavior
# <li>More human behavior is publicly observable than ever before
# <li>Supports sociology, anthropology, economics, psychology...
# <li>New algorithms are needed to sift through noise to find true patterns.
# <li>**Computational Social Science**
# </ul>
# </td></tr></table>
#
# <br><br><br><br>

# %% [markdown]
# ## This course combines...
# - Social network analysis
# - Natural language processing
# - Machine learning
#
# <br><br><br><br>
# <br><br><br><br>

# %% [markdown]
# ## Social Network Analysis
# - Study of the relationship between objects
# - Core tasks:
#   - Community detection
#   - Link prediction
#   - Spread of influence
#
#   <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Natural Language Processing
# - Algorithms allowing computers to make sense of human language
#   - text / audio
# - Core tasks:
#   - syntactic parsing
#   - entity/relation extraction
#   - sentiment classification
# - CS585
#
#   <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Machine Learning
# - Algorithms to detect patterns in data
# - Combines statistics and computer science
# - *CS584 Machine Learning*
#
# **Key tasks**
# - **Classification:** Assign a label to an object
# - **Regression:** Assign a real number to an object
# - **Clustering:** Group similar objects
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## This Course
# - Hands-on overview of social network, text analysis, machine learning
# - Survey of cutting edge research in this area
# - Technologies we'll use:
#   - Python / Jupyter notebooks
#   - Github
#   - Math
#   - Many APIs (Twitter, Facebook, LinkedIn, ...)
# - We'll use real data whenever possible
#   - Data are messy
#
# Course Website: <https://github.com/iit-cs579/main>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Why Jupyter Notebook?
#
# - Interactive; more fun.
# - See the code behind the math.
# <br><br><br><br><br>

# %% [markdown]
# $$ f(x) = \sum_i x_i $$
#
# <br><br><br>

# %%
def my_sum(x):
    total = 0
    for xi in x:
        total += xi
    return total

my_sum([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 45

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(5)*10, [50, 75, 85, 95, 99], 'bo-')
plt.xlabel('hours studying', size=14)
plt.ylabel('grade', size=14)
plt.show()

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### What are people saying about Oprah Winfrey right now?

# %%
import configparser
from TwitterAPI import TwitterAPI

def get_twitter(config_file):
    """ Read the config_file and construct an instance of TwitterAPI.
    Args:
      config_file ... A config file in ConfigParser format with Twitter credentials
    Returns:
      An instance of TwitterAPI.
    """
    config = configparser.ConfigParser()
    config.read(config_file)
    twitter = TwitterAPI(
                   config.get('twitter', 'consumer_key'),
                   config.get('twitter', 'consumer_secret'),
                   config.get('twitter', 'access_token'),
                   config.get('twitter', 'access_token_secret'))
    return twitter

twitter = get_twitter('twitter.cfg')
print('Established Twitter connection.')
# Out:
# Established Twitter connection.

# %%
request = twitter.request('search/tweets', {'q': 'oprah', 'count': 100}) 
tweets = [r for r in request]

# %%
tweets[0]['user']
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Tue Apr 29 21:26:05 +0000 2014',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Advertising with Spanish Undergrad |London |Malcom X |',
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'neoteric-soul.tumblr.com',
#      'expanded_url': 'http://neoteric-soul.tumblr.com',
#      'indices': [0, 23],
#      'url': 'https://t.co/8fNwWoASvZ'}]}},
#  'favourites_count': 9951,
#  'follow_request_sent': False,
#  'followers_count': 524,
#  'following': False,
#  'friends_count': 461,
#  'geo_enabled': False,
#  'has_extended_profile': False,
#  'id': 2517653536,
#  'id_str': '2517653536',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 15,
#  'location': '',
#  'name': 'Afwitjen',
#  'notifications': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2517653536/1499527841',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/891323825643769856/nyCI8X6h_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/891323825643769856/nyCI8X6h_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'neoteric_soul',
#  'statuses_count': 57817,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': 'https://t.co/8fNwWoASvZ',
#  'utc_offset': None,
#  'verified': False}

# %%
[t['text'] for t in tweets]
# Out:
# ['RT @XavierDLeau: This "Oprah for President" has gotten really weird.\n\nI think the conversation should be focused on what she actually said…',
#  'RT @GMB: Should Oprah Winfrey run for president? Donald Trump’s former press secretary Sean Spicer doesn’t think she has the ‘political inf…',
#  '@kencampbell66 @RicoColon1 @gatewaypundit Good job OPRAH!',
#  'RT @benjaminwittes: While everyone is talking about Oprah and the Golden Globes, I want to talk about the Oscars—and a guy named Grigory Ro…',
#  "RT @nytimes: Best: Oprah Winfrey's speech, Natalie Portman's one-liner \nWorst: Mostly silent men, some of those red-carpet interviews https…",
#  'So much more than just an acceptance speech, it was one of the most powerful, inspirational, empowering speech ever… https://t.co/4ISeCReCjU',
#  "RT @BUSSCRO: 2016: Can't imagine a worse candidate than Chelsea fucking Clinton\n\n2017: Can't imagine a worse candidate than Mark fucking Zu…",
#  '@WMUR9 she would lose! Oprah is not the end all and be all genius e1 thinks she is! she is like Merv, Donahue, and… https://t.co/BZ1bhxfzad',
#  "RT @rebeccawatson: seeing a lot of praise for this and I agree she's an incredible, inspiring woman. she's also a bullshit peddler who is r…",
#  'RT @VOANoticias: Oprah Presidente? Sus seguidores en Twitter aplauden la idea https://t.co/4NVE5K0Eiy https://t.co/ZV1N9PBNGo',
#  'Vote na Oprah kkkk eu votaria. https://t.co/c0ErCbiqI9',
#  "I really don't want to vote for Oprah. I really don't like this trend of voting for billionaire celebrities. I will… https://t.co/TNH0PTGPmu",
#  'RT @blackvoices: Oprah is the first Black woman to be honored with the Cecil B. DeMille Award at the #GoldenGlobes. https://t.co/ojjzWwYjvi',
#  "Even if she didn't run for president, imagine if Oprah was Secretary of State... with a woman in there finally we'd… https://t.co/ZMUpr8fYdP",
#  'RT @3lectric5heep: Flashback: Actress Says Weinstein Used Oprah to Lure Her to His Room #MeToo https://t.co/7IPEkpmp5E @3lectric5heep',
#  'RT @conurbaboy: Hollywood ayer: todas las mujeres de negro por los abusos y Oprah dando discurso diciendo "no más".\nArgentina hoy: Cacho Ca…',
#  "RT @boredbarbara: Oprah started off with 0 money and she turned it into billions . That's inspiring not white men from a lineage of rich fu…",
#  '@sportsmt If Oprah wins does everyone in America get a new car?',
#  '@stepale @CharlesMBlow No more neophytes. I love Oprah, but she has no foreign policy knowledge or experience, does… https://t.co/u0QDNc026U',
#  'Oprah’s Golden Globe speech definitely had me in tears. What a woman.',
#  'RT @JamesMelville: Oprah Winfrey / Michelle Obama to run against Donald Trump / Mike Pence in 2020?\nIf this happened, it would be the ultim…',
#  '@adamclanton @astros @Oprah EXACTLY  !!!!!',
#  'RT @SarahKSilverman: Oprah/Michelle 2020',
#  'Oprah Tells Gayle To Lotion Before Globes, Sets New BFF Bar https://t.co/0OUEgPHhvh https://t.co/8OZ4GZje1V',
#  'RT @PetroValverde: El discurso de Oprah Winfrey que debería estar en los libros de historia https://t.co/MdGEWeYyJs vía @elle_es #LifeStyle…',
#  "RT @ccarrollbeard: Hey guys, @Oprah is not presidential material any more than @realDonaldTrump was. She's a MUCH better person, but she's…",
#  'RT @josephamodeo: For more than three decades, @Oprah has been inspiring others, giving a voice to the voiceless, and telling stories that…',
#  "RT @RealSaavedra: THE LEFT: Trump's a billionaire tv-star who has no political experience, we need to replace him!\n\nALSO THE LEFT: #Oprah,…",
#  "RT @nytimes: Best: Oprah Winfrey's speech, Natalie Portman's one-liner \nWorst: Mostly silent men, some of those red-carpet interviews https…",
#  'RT @ExDemLatina: 🚨🚨🚨\n\n#FlashbackFriday on #MondayMotivation\n\nOprah saying older generation of Americans just have to die.  Probably the sam…',
#  'RT @donnabrazile: What is the best part about Oprah running for president? She can announce it by telling everybody to look under their sea…',
#  'can we give Oprah an Emmy for her golden globes speech 🤔',
#  'RT @NarchoVig: Oprah as President: "You get a drone strike! And you get a drone strike! Everybody gets a drone strike!"',
#  "RT @ScottAdamsSays: My prediction about Oprah is that she's too smart to run for president. She knows she'd get slaughtered. No reason to r…",
#  'Yeah, make Oprah President. Or, you know, a fucking politician.',
#  'RT @onesarahjones: good morning! anyone who sincerely thinks Oprah should run for president ought to be banned from writing about politics,…',
#  'RT @akhbar: #أوبرا_وينفري تلقي خطابا ملهما عن #التحرش بعد فوزها بجائزة تاريخية في الغولدن غلوب 2018\n#عيش_الآن #GoldenGlobes2018  \nللتفاصيل…',
#  'RT @goldenglobes: “I want all of the girls watching here now to know, that a new day is on the horizon.” @Oprah accepts the 2018 Cecil B. d…',
#  'RT @BillKristol: And, of course: Oprah came from infinitely more challenging circumstances than Trump, is wealthier than Trump, has read mo…',
#  'RT @OnlyMattBomer: @MattBomer @Oprah Omg i hope she runs for office and save your country from all this mess. it’s sad and scary seeing it…',
#  '@valerie_millett @Oprah @HarveyWeinstein @goldenglobes But that’s why I’m an entrepreneur! https://t.co/1RvWaLckJo',
#  'So much for the heroic speech last night!\nActress: Weinstein used Oprah and Naomi to seduce me https://t.co/iWo0b7f8JM via @pagesix',
#  'RT @Phil_Lewis_: Oprah is telling the story of  #RecyTaylor right now. This is an amazing speech. #GoldenGlobes https://t.co/Q7OhQY7Yhh',
#  "RT @SRuhle: I had no plans to open the email w/ subject line: Spicer on Oprah\nThen i did...\n“Sean Spicer says Oprah Winfrey doesn't have th…",
#  'RT @HistoriaEnFotos: Video: El discurso de Oprah Winfrey que se llevó la noche en los Globos de Oro \n\nhttps://t.co/pZQOlhuVXF',
#  "Jim Kunstler On Showbiz, Politics, &amp; The Oprah 'Fairy Tale' https://t.co/fCzLdR4E1j #Money #Finance #Economics #Market",
#  '@O_Magazine @Oprah If u have not see watch it’s amazing',
#  'RT @RWitherspoon: I will now officially divide time like this : Everything that happened before @Oprah speech : Everything that will happen…',
#  'RT @ChristiChat: #OprahKnew\nOprah approved. https://t.co/DMjSUAcnXH',
#  'RT @RWitherspoon: It was the deepest honor to present @Oprah with the #CecilBDeMille award this #GoldenGlobes. It was an even bigger honor…',
#  "Jim Kunstler On Showbiz, Politics, &amp; The Oprah 'Fairy Tale' https://t.co/F3ydvoSgCg",
#  'RT @RubinReport: Trump 2016\nOprah 2020\nChelsea 2024\nMalia 2028\nBieber 2032\n\nGREAT HUMAN-ROBOT WAR\n\nCylon 2036\nKeurig Machine 2040\n\nGREAT HU…',
#  "RT @O_Magazine: Watch @Oprah's full Cecil B. DeMille Award acceptance speech at the 75th #GoldenGlobes. #TIMESUP https://t.co/4MDm2aRlEi",
#  "RT @herenowhere3: Because Oprah is an entertainment figure turned self help guru &amp; Hillary is a policy wonk.\nGuess which one I'd rather run…",
#  'THE BUZZ IS BACK https://t.co/wFsUbMvR10',
#  '@seanhannity REPLAY THE VIDEO WHEN TRUMP BROUGHT UP OPRAH TO BE HIS RUNNING MATE!!',
#  'RT @kencampbell66: Flashback: British Actress Says Weinstein Used Oprah to Lure Her to His Room #MeToo https://t.co/fWqWoDvB3H via @gateway…',
#  'RT @davidaxelrod: Imagine what @Oprah could do for the auto industry if EVERYBODY got a car?',
#  'RT @seanhannity: THIS IS CNN: Network Host FANTASIZES About Possible Oprah Presidency\n \nhttps://t.co/comTIdskY0',
#  'RT @MattBomer: Thank you @Oprah just thank you. You’ve had my vote for ANY office since about 1988.',
#  "Oprah Winfrey's Inspirational Cecil B. de Mille Award Speech #metoo #anewday  https://t.co/YizjtWyTdy",
#  'RT @victoriabeckham: I am so moved to witness the solidarity of women and men everywhere, across all industries, unite in their support of…',
#  'RT @Albert_Rivera: Valiente discurso de @Oprah anoche en los Globos de Oro. Un alegato a favor de la igualdad y en homenaje al coraje de ta…',
#  'RT @snoozinglion1: @DineshDSouza Actress: Weinstein used Oprah and Naomi to seduce me https://t.co/hPzFnpXMrt',
#  'RT @BlakeMirolla: I love Oprah as much as the next guy but like....................are we really giving up on finding qualified candidates…',
#  'NBC Deletes ‘President Oprah’ Tweet After Backlash https://t.co/LauNEh67eX via @realalexjones',
#  'Where in Oprah’s speech did you politically not intelligent folks get she’s running for President ? Stop',
#  'RT @DineshDSouza: How many shows did Oprah do over all those years exposing sexual predation in Hollywood? Let me count. NONE',
#  'RT @ehosseh: #Oprah didn’t have daddy’s money to start her businesses like Trump did. She was born into poverty and is now one of the riche…',
#  'Oprah Winfrey now that the Republicans and Trump have turned the presidency into a Goddamn popularity contest mr. and Mrs. America pageant',
#  'RT @RealAlexJones: Oprah Winfrey Will Never Be Elected President Because Of This Secret https://t.co/jjfMcqoSip',
#  'I love Oprah, her speech was great, but maybe the entertainment industry isn’t the pool we should be picking our pr… https://t.co/NhlTtxU6vR',
#  'RT @joehas: Even if you already know the content you should watch Oprah´s speech just for the delivery. She came with something to say and…',
#  'RT @ButeraDemetria: Oprah stole the night. https://t.co/DeshDfa2hq',
#  'RT @goldengateblond: Here’s @Oprah’s entire speech. Watch it. If you’ve already seen it, watch it again. #MeToo #TimesUp https://t.co/cAcVJ…',
#  'RT @Slate: Oprah’s record of promoting charlatans should maybe give us pause about her impending presidency https://t.co/e7gB1Po1b3 https:/…',
#  'RT @zesty_rightwing: Flashback: British Actress Says Weinstein Used Oprah to Lure Her to His Room #MeToo https://t.co/0HUMRux6xr https://t.…',
#  "RT @FiveRights: I live 2,000 miles from Hollywood and I'm not in the business and I knew  about Weinstein, so Oprah Winfrey sure as hell kn…",
#  'RT @amandalitman: “Oprah’s speech—in my hearing—wasn’t about why she needs to run for office. It was about why the rest of us need to do so…',
#  'RT @femaleACEs: Today\'s dose of motivation brought to you by #Oprah: "For too long women have not been heard or believed if they dared to s…',
#  'RT @SarahKSilverman: Oprah/Michelle 2020',
#  '@reason if so, @Oprah has a LOT of explaining to do. #ShesComplicit https://t.co/1WwN7hHheL',
#  'RT @Slate: Oprah’s record of promoting charlatans should maybe give us pause about her impending presidency https://t.co/e7gB1Po1b3 https:/…',
#  '@Oprah is a success in business, in acting, in authorship, is highly intelligent and articulate, is self-made. Seem… https://t.co/5akDLlSeOx',
#  'RT @elisewell63: @JackPosobiec @Monica4Trump Because of Oprah we got Obama and it did not turn out well. No, thank you🙄',
#  "RT @ARTPOPVENUS87: Yes @Oprah I'll be the first to Vote for You it's About time a Woman to Stand Up 🙌 https://t.co/Y1ValHem0b",
#  "RT @mitchellvii: Oprah's show(s) were cancelled.  Trump's weren't.",
#  'RT @GOATeminemRap: Eminem Fight Music cover by @realjoefewster #GoldenGlobes\xa0\xa0\xa0#GoldenGlobe\xa0#Oprah Oscar Nicki Minaj Rihanna Rap Music Drak…',
#  "RT @stealthygeek: No.\n\nNo Trump.\n\nNo The Rock.\n\nNo Oprah.\n\nJust, fuck no.\n\nExperienced. Politician.\n\nWant a woman of color? Awesome. I'm ri…",
#  'RT @BasedMonitored: Oprah wants older whites to die. \n\nShe thought we’d forget about this. https://t.co/toYE7DcCCf',
#  "RT @PrisonPlanet: Hollywood covered up Weinstein's abuse for decades, but Oprah zeroed in on who's really responsible.\n\nWhite people and Tr…",
#  'RT @BorisEP: Afternoon! NBC issues a denial/apology re. tweet on Oprah for President - I’m not buying it; @VP is traveling to Middle East o…',
#  "There's a must-watch documentary about Recy Taylor, the important woman Oprah shouted out in her Globes speech https://t.co/Qzq7fVWJZn",
#  'RT @romyreiner: While it would be cool to have Oprah as President, we need people with real government and political backgrounds running fo…',
#  'RT @common: “Speaking your truth is the most powerful tool we all have" @Oprah at the #GoldenGlobes https://t.co/lWpwdFWaWA',
#  'RT @seanhannity: THIS IS CNN: Network Host FANTASIZES About Possible Oprah Presidency\n \nhttps://t.co/comTIdskY0',
#  'RT @RedPillBlack: Take a second to realize that @Oprah gave a speech last night--not on the economy, not on foreign trade, not on her stanc…',
#  'Who is Racy Taylor? A documentary highlights woman Oprah shouted out https://t.co/E6RwBNPA0V',
#  "RT @atensnut: Remember this @Oprah    You've had so many opportunities to bring up my allegations, which have never been discredited. Why??…",
#  "I mean #Oprah's fine. But. There. Are. So. Many. Qualified. Women. So it's just some more #sexist shit when she's put forward as our savior."]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(t['text'] for t in tweets)
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:30]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                oprah	94
#                   rt	70
#                https	42
#               speech	17
#            president	13
#        oprah winfrey	11
#              winfrey	11
#                trump	10
#         goldenglobes	8
#                woman	8
#            weinstein	7
#                  run	7
#                 just	6
#                 like	5
#      oprah president	5
#                metoo	5
#                 used	5
#           used oprah	5
#         oprah speech	5
#                watch	5
#       weinstein used	5
# weinstein used oprah	5
#           presidency	5
#              actress	5
#                  did	5
#        run president	4
#                  men	4
#             discurso	4
#              running	4
#                cecil	4

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(t['text'] for t in tweets)
wordcloud = WordCloud(width=1200, height=800, background_color="white", 
                      stopwords=STOPWORDS).generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # First assignment, 999,999,999 points
#
# Complete the course survey!
# https://goo.gl/forms/QqSuILOWBDCh8cF32
#
# as soon as possible
#
#
# <br><br><br>

# %%
import pandas as pd
data = pd.read_csv('survey_results.csv')
headers = ['How familiar are you with version control? (git, svn, mercurial, cvs, etc.)',
          'How familiar are you with Python?',
          ]

for h in headers:
    plt.figure()
    data[h].plot(kind='hist')
    plt.ylabel('count')
    plt.xticks(np.arange(1, 6))
    plt.title(h)
plt.show()

# %%
from collections import Counter
mlq = 'Have you taken a course on Machine Learning or Data Mining?'
mlclass = Counter(data[mlq])
plt.figure()
plt.title(mlq)
plt.bar([0, 1], mlclass.values(), width=.5)
plt.xticks([0, 1], mlclass.keys())
plt.ylabel('count')
plt.show()

# %%
# Why take this course question.
# Note: this wont work since I removed this column from the data in github.
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(data['Why are you taking this course?'])
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:20]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                 data	11
#                learn	10
#               social	10
#             analysis	6
#                 want	5
#               course	5
#           want learn	4
#              network	4
#       social network	4
#        online social	4
#               online	4
#             learning	3
#       data analytics	3
#              analyze	3
#           media data	3
#            analytics	3
#             networks	3
#                media	3
#           algorithms	3
#               people	3

# %%
# Top words for people who have taken ML/DM
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(text, data[mlq])
print('\n'.join(words[np.argsort(clf.coef_[0])[::-1][:10]]))
# Out:
# data
# practical
# analyze
# networks
# social networks
# interested
# social
# analyzing
# skills
# algorithms

# %%
# Top words for people who have NOT taken ML/DM
print('\n'.join(words[np.argsort(clf.coef_[0])[:10]]))
# Out:
# programming
# field
# network
# social network
# machine learning
# machine
# really
# analyzed
# want learn
# learn online

# %% [markdown]
# **Any insights?**
#
# <br><br><br><br>
# https://github.com/iit-cs579/main
