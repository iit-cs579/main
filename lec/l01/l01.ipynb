# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
#
#
# <center>
# <b><font size="+3">CS579: Online Social Network Analysis </font></b>
# <br>
# **Lecture 01**
# *[Dr. Aron Culotta](http://cs.iit.edu/~culotta)*
# *[Illinois Institute of Technology](http://iit.edu)*
#
# </center>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# What is an **online social network?**
#
# <br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 50px;">
# <img width=50% src="images/fb_logo.png"/>
# </span>
#
# - 1.2B users
# - 70B pieces of content shared / day
# - 150K messages sent / minute
#
# Sources: [\[1\]](http://www.statisticbrain.com/facebook-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/twitter_logo2.png"/>
# </span>
#
# <br>
#
# - 560M users
# - 400M tweets / day
# - 170B total tweets
#
# Sources: [\[1\]](http://www.statisticbrain.com/twitter-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/instagram.png"/>
# </span>
# <br>
#
# - 4B shared photos
# - 5M photos / day
# - 81 comments / second
#
# Sources: [\[1\]](http://www.huffingtonpost.com/brian-honigman/100-fascinating-social-me_b_2185281.html)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/sina-weibo.png"/>
# </span>
# <br>
#
# - 261M active users
# - 470M daily video views
# - 100M posts / day
#
# Sources: [\[1\]](http://expandedramblings.com/index.php/weibo-user-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### A large portion of the world's conversations are conducted in public.

# %% [markdown]
# ### Is there anything useful in this chatter?

# %% [markdown]
# ![brand](images/brand.png)
#
# [Radian6](http://www.salesforcemarketingcloud.com/blog/2012/08/social-media-insights-peekanalytics-at-work/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![flu](images/flu.png)
#
# - [Paul & Dredze \[2011\]](http://www.cs.jhu.edu/~mdredze/publications/twitter_health_icwsm_11.pdf)
# - [Culotta \[2010\]](http://cs.iit.edu/~culotta/pubs/culotta10towards.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![gallup](images/gallup.png)
#
# [O'Connor et al. \[2010\]](http://www.cs.cmu.edu/~nasmith/papers/oconnor+balasubramanyan+routledge+smith.icwsm10.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![djia](images/djia.png)
#
# [Bollen et al. \[2010\]](http://arxiv.org/pdf/1010.3003v1.pdf)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![crisis](images/crisis.png)
#
# [Rogstadius et al. \[2013\]](http://ufn.virtues.fi/~jakob/twitter/about.php)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![earthquake](images/earthquake.png)
#
# [Kumar et al. \[2011\]](http://www.public.asu.edu/~mabbasi2/papers/kumar2011tweettracker.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# **How does this** ![tweets](images/tweets.png) **become useful?**
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ###  Algorithms + Data = The Microscope of the 21st Century
#
# <table style="border: none;border-collapse: collapse;" border="0" >
# <tr><td><img src="images/tree.png" width=80%></td>
# <td>
# <ul>
# <li>Much as the microscope allowed scientists to see things they previously couldn't, now computer science provides new windows into human behavior
# <li>More human behavior is publicly observable than ever before
# <li>Supports sociology, anthropology, economics, psychology...
# <li>New algorithms are needed to sift through noise to find true patterns.
# <li>**Computational Social Science**
# </ul>
# </td></tr></table>
#
# <br><br><br><br>

# %% [markdown]
# ## This course combines...
# - Social network analysis
# - Natural language processing
# - Machine learning
#
# <br><br><br><br>
# <br><br><br><br>

# %% [markdown]
# ## Social Network Analysis
# - Study of the relationship between objects
# - Core tasks:
#   - Community detection
#   - Link prediction
#   - Spread of influence
#
#   <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Natural Language Processing
# - Algorithms allowing computers to make sense of human language
#   - text / audio
# - Core tasks:
#   - syntactic parsing
#   - entity/relation extraction
#   - sentiment classification
# - CS585
#
#   <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Machine Learning
# - Algorithms to detect patterns in data
# - Combines statistics and computer science
# - *CS584 Machine Learning*
#
# **Key tasks**
# - **Classification:** Assign a label to an object
# - **Regression:** Assign a real number to an object
# - **Clustering:** Group similar objects
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## This Course
# - Hands-on overview of social network, text analysis, machine learning
# - Survey of cutting edge research in this area
# - Technologies we'll use:
#   - Python / Jupyter notebooks
#   - Github
#   - Math
#   - Many APIs (Twitter, Facebook, LinkedIn, ...)
# - We'll use real data whenever possible
#   - Data are messy
#
# Course Website: <https://github.com/iit-cs579/main>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Why Jupyter Notebook?
#
# - Interactive; more fun.
# - See the code behind the math.
# <br><br><br><br><br>

# %% [markdown]
# $$ f(x) = \sum_i x_i $$
#
# <br><br><br>

# %%
def my_sum(x):
    total = 0
    for xi in x:
        total += xi
    return total

my_sum([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 36

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(5)*10, [50, 60, 70, 90, 100], 'bo-')
plt.xlabel('hours studying', size=14)
plt.ylabel('grade', size=14)
plt.show()

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### What are people saying about the eclipse right now?

# %%
import configparser
from TwitterAPI import TwitterAPI

def get_twitter(config_file):
    """ Read the config_file and construct an instance of TwitterAPI.
    Args:
      config_file ... A config file in ConfigParser format with Twitter credentials
    Returns:
      An instance of TwitterAPI.
    """
    config = configparser.ConfigParser()
    config.read(config_file)
    twitter = TwitterAPI(
                   config.get('twitter', 'consumer_key'),
                   config.get('twitter', 'consumer_secret'),
                   config.get('twitter', 'access_token'),
                   config.get('twitter', 'access_token_secret'))
    return twitter

twitter = get_twitter('twitter.cfg')
print('Established Twitter connection.')
# Out:
# Established Twitter connection.

# %%
request = twitter.request('search/tweets', {'q': 'eclipse', 'count': 100}) 
tweets = [r for r in request]

# %%
[t['text'] for t in tweets]
# Out:
# ['RT @DAILUVV: fuck the eclipse',
#  'RT @SCHNEE326: #EXO #ThePowerofMusic #TotalEclipse #Total_Eclipse https://t.co/7F6ZAEJxxG',
#  "RT @stefanmymind: Aaaaaand here's your photo of Trump looking straight at the eclipse https://t.co/5vv6sVTDIl",
#  'Corporate America came out their buildings to watch the solar eclipse today. Meanwhile, this stubborn idiot really… https://t.co/spAdGubkEi',
#  "RT @itsalliegator_: That's it, this is my favorite tweet about the eclipse. https://t.co/BBukvQamNY",
#  '@abc27 - eclipse through the special glasses from the Capitol Complex https://t.co/cBQ4NJHZgY',
#  'RT @magoya2001: Tanto despelote x un eclipse de morondanga. Aca tenemos al Nestor orbitando en el Arsatll y nadi dice nada.',
#  "RT @_MsQu33nSteph: It's funny because some of y'all looked harder for those Eclipse Glasses than a JOB!! 🙄😂🤦🏽\u200d♀️",
#  'Just destroyed my camera getting the eclipse but worth it https://t.co/dEDjhjN40j',
#  'RT @danielaescobar: Hoy me pidieron clases particulares y yo: hoy es el eclipse.',
#  'Muchos políticos deberían ver el eclipse directamente, sin lentes, por un largo tiempo, tal vez justifique lo del ojo pacho 😒',
#  'RT @HilariousEdited: IN CASE YOU MISSED THE TOTAL ECLIPSE 🌕🌖🌗🌘🌑🌒🌓🌔🌕 https://t.co/herd4UkBs1',
#  'RT @HistoriaEnFotos: Impresionante, como se ve el #Eclipse\xa0 desde un avión https://t.co/AbxGF4LhxX',
#  'No filter, just my Samsung S8 and the cloud that passed over the eclipse at… https://t.co/VESMBSUfIN',
#  'DID the eclipse take our national debt with it?',
#  'Eclipse 2017 #eclipse2017 https://t.co/QKsKX1DVcf',
#  'RT @memeprovider: IN CASE YOU MISSED THE TOTAL ECLIPSE 🌕🌖🌗🌘🌑🌒🌓🌔🌕 https://t.co/mdg34mm8qu',
#  'RT @luscas: decidindo que roupa devo usar no eclipse',
#  'RT @xHiji: This solar eclipse is really killing my libido..',
#  'RT @OpTic_Scumper: The eclipse sorta just pissed me off',
#  'RT @GaryHershorn: The eclipse over the #empirestatebuilding in NYC #newyork #newyorkcity  #Eclipse2017 #GreatAmericanEclipse @NYCDailyPics…',
#  'How long until the loss meme of various phases of the eclipse',
#  'Even the Bitmojis watching the eclipse https://t.co/iGZGJc2XAJ',
#  'RT @TheAn1meMan: On the day of the eclipse...!\nAki is Griffith confirmed.\n\nCongratulations baby, so proud of you &lt;3 xoxo https://t.co/T6pVQ…',
#  'The official dessert of the #eclipse @MoonPie https://t.co/4Xu5wXD8QF',
#  "RT @d_hirsty: Melania: Don't look into the eclipse, Donald.\n\nPresident Trump: says who?\n\nMelania: CNN\n\nPresident Trump: Fake News! \n\n#Solar…",
#  'RT @Rod_lopez: Que privilegio volar mientras se presenta el #Eclipse https://t.co/QRb9mEtey2',
#  'RT @AMarshallSport: Partial eclipse of the court? New No. 1 Rafa #Nadal is the brightest player in tennis right now, but even he had to loo…',
#  'RT @CBSNews: WATCH: The sky turns pitch black in Jackson Hole, Wyoming as #SolarEclipse2017 reaches totality https://t.co/1qs7yHw5uJ https:…',
#  'RT @TheBabylonBee: Lakewood Church Issues Eclipse Glasses For Gazing At Joel Osteen’s Teeth https://t.co/WvAhdO91Eu https://t.co/YdjuCPWguG',
#  'RT @pewdiepie: If its a true eclipse then why can you look at it? fake eclipse confirmed',
#  'Eclipse 2017 in Greenville, SC https://t.co/5KWwsMSG16',
#  'RT @totorolls: the eclipse is so beautiful https://t.co/OJ6j4MPfA8',
#  'RT @GoT_Tyrion: When we have an eclipse in Westeros #SolarEclipse2017 https://t.co/zPwX3B5U3M',
#  "If now one had told me there was going to be a partial eclipse today in West Virginia I wouldn't have known it...but it did 👀 cool with the😎",
#  'RT @mineifiwildout: locals b like ..\n\nsolar eclipse n chill? 🙈\n\n3 Retweets 8 Likes\n\n.\n\ndam .. this blew up 😧 while i got yal here follow my…',
#  'RT @KFILE: For those not in North America, this is what the eclipse might look like https://t.co/GwKldjK3MR',
#  'RT @brian_something: Solar Eclipse 2017 did 9/11',
#  'RT @davispemberton: You fools happy. That eclipse was such a let down',
#  "RT @usedpizza: Made a time-lapse gif of today's eclipse, the end has me a little bit worried though #SolarEclipse2017 #Eclipse2017 https://…",
#  'In other news, when everyone went out in to the parking lot to see the eclipse, one of the women in the building had a colander... 😬',
#  'RT @SGiven12: @PriscoCBS I captured the Total Eclipse ... https://t.co/bGvQrb0euA',
#  'RT @yc: When u nut but the eclipse still sucking https://t.co/qdbE83mETz',
#  "@TornadoLizard That cloud ain't got shit on that eclipse! XD",
#  'RT @Applexiu: 개기일식날 total eclipse 티저 공개하는거 좀 개존멋이긴해....']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(t['text'] for t in tweets)
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:30]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#              eclipse	96
#                   rt	73
#                https	59
#        eclipse https	20
#                solar	18
#        solar eclipse	17
#                   el	10
#           el eclipse	9
#     solareclipse2017	8
#                 look	7
#                  sun	7
#                trump	7
#                total	7
#              glasses	7
#                today	6
#              looking	5
#        total eclipse	5
#          eclipse2017	5
# solareclipse2017 https	5
#      eclipse glasses	5
#             directly	5
#                 time	5
#               missed	5
#                 2017	5
#  total eclipse https	4
#                 just	4
#     el eclipse https	4
#         eclipse 2017	4
#                 shit	4
#                  did	4

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(t['text'] for t in tweets)
wordcloud = WordCloud(width=1200, height=800, background_color="white", 
                      stopwords=STOPWORDS | set(['eclipse', 'solar', 'rt', 'https', 'co'])).generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # First assignment, 999,999,999 points
#
# Complete the course survey!
# https://goo.gl/forms/Wk857dasCGQBoUjm1
#
# as soon as possible
#
#
# <br><br><br>

# %%
import pandas as pd
data = pd.read_csv('survey_results.csv')
headers = ['How familiar are you with version control? (git, svn, mercurial, cvs, etc.)',
          'How familiar are you with Python?',
          ]

for h in headers:
    plt.figure()
    data[h].plot(kind='hist')
    plt.ylabel('count')
    plt.xticks(np.arange(1, 6))
    plt.title(h)
plt.show()

# %%
from collections import Counter
mlq = 'Have you taken a course on Machine Learning or Data Mining?'
mlclass = Counter(data[mlq])
plt.figure()
plt.title(mlq)
plt.bar([0, 1], mlclass.values(), width=.5)
plt.xticks([0, 1], mlclass.keys())
plt.ylabel('count')
plt.show()

# %%
# Why take this course question.
# Note: this wont work since I removed this column from the data in github.
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(data['Why are you taking this course?'])
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:20]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#               social	20
#             analysis	13
#                learn	12
#                 data	11
#              network	10
#           interested	10
#       social network	9
#            knowledge	8
#                 help	7
#               course	7
#                 want	7
#               python	7
#     machine learning	6
#             learning	6
#              machine	6
#                 work	6
#              analyse	5
#         intelligence	5
#     network analysis	4
#               really	4

# %%
# Top words for people who have taken ML/DM
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(text, data[mlq])
print('\n'.join(words[np.argsort(clf.coef_[0])[::-1][:10]]))
# Out:
# important
# related
# related social
# online
# online social
# learn analyse
# area
# real
# techniques
# make

# %%
# Top words for people who have NOT taken ML/DM
print('\n'.join(words[np.argsort(clf.coef_[0])[:10]]))
# Out:
# intelligence
# worked
# told
# way
# skill
# lot
# working
# computational intelligence
# computational
# understand

# %% [markdown]
# **Any insights?**
