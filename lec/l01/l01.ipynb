# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
#
#
# <center>
# <b><font size="+3">CS579: Online Social Network Analysis </font></b>
# <br>
# **Lecture 01**
# *[Dr. Aron Culotta](http://cs.iit.edu/~culotta)*
# *[Illinois Institute of Technology](http://iit.edu)*
#
# </center>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# What is an **online social network?**
#
# <br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 50px;">
# <img width=50% src="images/fb_logo.png"/>
# </span>
#
# - 1.7B users
# - 70B pieces of content shared / day
# - 150K messages sent / minute
#
# Sources: [\[1\]](http://www.statisticbrain.com/facebook-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/twitter_logo2.png"/>
# </span>
#
# <br>
#
# - 700M users
# - 58M tweets / day
# - >200B total tweets
#
# Sources: [\[1\]](http://www.statisticbrain.com/twitter-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/instagram.png"/>
# </span>
# <br>
# - 500M active users
# - 40B shared photos
# - 95M photos / day
# - 100 comments / second
#
# Sources: [\[1\]](http://www.huffingtonpost.com/brian-honigman/100-fascinating-social-me_b_2185281.html) [\[2\]](https://blog.hootsuite.com/instagram-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/sina-weibo.png"/>
# </span>
# <br>
#
# - 360M active users
# - 2B daily video views
# - 100M posts / day
#
# Sources: [\[1\]](http://expandedramblings.com/index.php/weibo-user-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### A large portion of the world's conversations are conducted in public.

# %% [markdown]
# ### Is there anything useful in this chatter?

# %% [markdown]
# ![brand](images/brand.png)
#
# [Radian6](http://www.salesforcemarketingcloud.com/blog/2012/08/social-media-insights-peekanalytics-at-work/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![flu](images/flu.png)
#
# - [Paul & Dredze \[2011\]](http://www.cs.jhu.edu/~mdredze/publications/twitter_health_icwsm_11.pdf)
# - [Culotta \[2010\]](http://cs.iit.edu/~culotta/pubs/culotta10towards.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![gallup](images/gallup.png)
#
# [O'Connor et al. \[2010\]](http://www.cs.cmu.edu/~nasmith/papers/oconnor+balasubramanyan+routledge+smith.icwsm10.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![djia](images/djia.png)
#
# [Bollen et al. \[2010\]](http://arxiv.org/pdf/1010.3003v1.pdf)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![crisis](images/crisis.png)
#
# [Rogstadius et al. \[2013\]](http://ufn.virtues.fi/~jakob/twitter/about.php)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![earthquake](images/earthquake.png)
#
# [Kumar et al. \[2011\]](http://www.public.asu.edu/~mabbasi2/papers/kumar2011tweettracker.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# **How does this** ![tweets](images/tweets.png) **become useful?**
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ###  Algorithms + Data = The Microscope of the 21st Century
#
# <table style="border: none;border-collapse: collapse;" border="0" >
# <tr><td><img src="images/tree.png" width=80%></td>
# <td>
# <ul>
# <li>Much as the microscope allowed scientists to see things they previously couldn't, now computer science provides new windows into human behavior
# <li>More human behavior is publicly observable than ever before
# <li>Supports sociology, anthropology, economics, psychology...
# <li>New algorithms are needed to sift through noise to find true patterns.
# <li>**Computational Social Science**
# </ul>
# </td></tr></table>
#
# <br><br><br><br>

# %% [markdown]
# ## This course combines...
# - Social network analysis
# - Natural language processing
# - Machine learning
#
# <br><br><br><br>
# <br><br><br><br>

# %% [markdown]
# ## Social Network Analysis
# - Study of the relationship between objects
# - Core tasks:
#   - Community detection
#   - Link prediction
#   - Spread of influence
#
#   <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Natural Language Processing
# - Algorithms allowing computers to make sense of human language
#   - text / audio
# - Core tasks:
#   - syntactic parsing
#   - entity/relation extraction
#   - sentiment classification
# - CS585
#
#   <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Machine Learning
# - Algorithms to detect patterns in data
# - Combines statistics and computer science
# - *CS584 Machine Learning*
#
# **Key tasks**
# - **Classification:** Assign a label to an object
# - **Regression:** Assign a real number to an object
# - **Clustering:** Group similar objects
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## This Course
# - Hands-on overview of social network, text analysis, machine learning
# - Survey of cutting edge research in this area
# - Technologies we'll use:
#   - Python / Jupyter notebooks
#   - Github
#   - Math
#   - Many APIs (Twitter, Facebook, LinkedIn, ...)
# - We'll use real data whenever possible
#   - Data are messy
#
# Course Website: <https://github.com/iit-cs579/main>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Why Jupyter Notebook?
#
# - Interactive; more fun.
# - See the code behind the math.
# <br><br><br><br><br>

# %% [markdown]
# $$ f(x) = \sum_i x_i $$
#
# <br><br><br>

# %%
def my_sum(x):
    total = 0
    for xi in x:
        total += xi
    return total

my_sum([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 45

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(7)*10, [50, 75, 85, 95, 99, 99, 99], 'bo-')
plt.xlabel('hours studying', size=14)
plt.ylabel('grade', size=14)
plt.show()

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ### What are people saying about Oprah Winfrey right now?

# %%
import configparser
from TwitterAPI import TwitterAPI

def get_twitter(config_file):
    """ Read the config_file and construct an instance of TwitterAPI.
    Args:
      config_file ... A config file in ConfigParser format with Twitter credentials
    Returns:
      An instance of TwitterAPI.
    """
    config = configparser.ConfigParser()
    config.read(config_file)
    twitter = TwitterAPI(
                   config.get('twitter', 'consumer_key'),
                   config.get('twitter', 'consumer_secret'),
                   config.get('twitter', 'access_token'),
                   config.get('twitter', 'access_token_secret'))
    return twitter

twitter = get_twitter('twitter.cfg')
print('Established Twitter connection.')
# Out:
# Established Twitter connection.

# %%
request = twitter.request('search/tweets', {'q': 'oprah', 'count': 100}) 
tweets = [r for r in request]

# %%
len(tweets)
# Out:
# 100

# %%
tweets[0]
# Out:
# {'created_at': 'Mon Jan 14 16:31:44 +0000 2019',
#  'id': 1084850561781022726,
#  'id_str': '1084850561781022726',
#  'text': 'RT @Zamantungwa_K: Applications for the Oprah Winfrey Leadership Academy for girls are open for the 2020 Grade 8 class. \n\nClosing Date is 1…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Zamantungwa_K',
#     'name': 'Zamantungwa',
#     'id': 134584377,
#     'id_str': '134584377',
#     'indices': [3, 17]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 2206421849,
#   'id_str': '2206421849',
#   'name': 'MissKayT 🇿🇦',
#   'screen_name': 'KhumoTsamai',
#   'location': 'Pretoria, South Africa',
#   'description': 'MoTswana girl. Sarcasm and dark humour enthusiast. Realest and realist. UKZN Alumni || Candidate Engineer/Girl of Steel || Agriculture',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 134,
#   'friends_count': 164,
#   'listed_count': 0,
#   'created_at': 'Tue Dec 03 20:36:29 +0000 2013',
#   'favourites_count': 2506,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 516,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1044510957286957057/CHCT8KFh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1044510957286957057/CHCT8KFh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2206421849/1545893336',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Mon Jan 14 13:16:49 +0000 2019',
#   'id': 1084801509110530053,
#   'id_str': '1084801509110530053',
#   'text': 'Applications for the Oprah Winfrey Leadership Academy for girls are open for the 2020 Grade 8 class. \n\nClosing Date… https://t.co/TzhSlUvJCC',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/TzhSlUvJCC',
#      'expanded_url': 'https://twitter.com/i/web/status/1084801509110530053',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 134584377,
#    'id_str': '134584377',
#    'name': 'Zamantungwa',
#    'screen_name': 'Zamantungwa_K',
#    'location': 'Johannesburg',
#    'description': 'Hiker | @wef Global Shaper @TshwaneHub | Real Estate | 3 333KM in 365 Days | TEDx Speaker | Moderator of Debates | Traveller |  Prodigious',
#    'url': 'https://t.co/26WI7oNDXQ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/26WI7oNDXQ',
#        'expanded_url': 'http://www.zamantungwakhumalo.com',
#        'display_url': 'zamantungwakhumalo.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5751,
#    'friends_count': 869,
#    'listed_count': 80,
#    'created_at': 'Sun Apr 18 21:33:48 +0000 2010',
#    'favourites_count': 4298,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 2979,
#    'lang': 'en-gb',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1076151708680638466/KIgqAUYV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1076151708680638466/KIgqAUYV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134584377/1451576881',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 41,
#   'favorite_count': 12,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 41,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
tweets[0]['user']
# Out:
# {'id': 2206421849,
#  'id_str': '2206421849',
#  'name': 'MissKayT 🇿🇦',
#  'screen_name': 'KhumoTsamai',
#  'location': 'Pretoria, South Africa',
#  'description': 'MoTswana girl. Sarcasm and dark humour enthusiast. Realest and realist. UKZN Alumni || Candidate Engineer/Girl of Steel || Agriculture',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 134,
#  'friends_count': 164,
#  'listed_count': 0,
#  'created_at': 'Tue Dec 03 20:36:29 +0000 2013',
#  'favourites_count': 2506,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 516,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1044510957286957057/CHCT8KFh_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1044510957286957057/CHCT8KFh_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2206421849/1545893336',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
[t['text'] for t in tweets]
# Out:
# ['RT @Zamantungwa_K: Applications for the Oprah Winfrey Leadership Academy for girls are open for the 2020 Grade 8 class. \n\nClosing Date is 1…',
#  'The Oprah Shrug and Waka Flocka okay are a 2019 forever mood',
#  '@think_teach1 @paigewolf @BrianSimsPA @RepMaxineWaters @CBS @RuPaul @Oprah You have no idea... sad',
#  'RT @bniceloco: Michael Jackson really lied to Oprah and said he was rusty then hit the moonwalk like it was nothing https://t.co/H3EHthULBD',
#  '@jujuberg18 @Oprah @SuperSoulSunday @BetoORourke @RepBetoORourke I heard you got tickets!! You are going to have the best time!!',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  'RT @RandyRainbow: The most important is @VaselineBrand Lip Therapy with cocoa butter (in the jar) of which I have cabinets full. It’s serio…',
#  'RT @jujuberg18: "COMING SOON: Tickets will go on sale this Monday, January 14 at 10a EST." But no live link to be found...🙁 @Oprah @SuperSo…',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  'My armpit smells like all my extrovert points yesterday with no soul walked in on dead Oprah.',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  'Man talking about Oprah and Hollywood on Facebook, “I truly believe they are pawns of Satan, used and strategically… https://t.co/n9QLhRrRBK',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  '@TheEllenShow @TraceeEllisRoss @MichelleObama @Oprah @Diddy please support Girl Scout Troop #18139 and buy cookies… https://t.co/opSejSOoNJ',
#  '@DrWardBondTV Life Changing Wellness is a cross between Oprah &amp; Dr Oz. We talk #naturalhealth, interview top expert… https://t.co/1PufqTeGI1',
#  '@StephenCurry30 @SteveKerr @Money23Green @MoneyLynch @DaveKaval @KingJames @BarackObama @Oprah @KevinHart4real… https://t.co/q4v3QFUCPw',
#  'RT @RandyRainbow: The most important is @VaselineBrand Lip Therapy with cocoa butter (in the jar) of which I have cabinets full. It’s serio…',
#  'RT @Born2TalkRadio: The word today is Communication. “The most important thing in Communication is hearing what isn’t said.” Peter Drucker.…',
#  '@Oprah  If you look up charlatan, quack, snake oil salesman, con artist, shill or medical fraud , you should see a… https://t.co/Ht0z2XP1JR',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  'RT
#  'From Beto to Oprah, Undeclared 2020 Candidates Already Backed by Outside Groups https://t.co/EDR8GfGxxy',
#  '#ICYMI Next month @BetoORourke will sit down for an interview with @Oprah in New York.\nhttps://t.co/yf0c1ruvYx',
#  'RT @NastromKenneth: @TheBadDadder @Oprah Yes, you’re right Paul, God will start revealing the truth of war through Vets that will finally t…',
#  'RT @The_Trump_Train: Walls don’t work, except at:\n\nBezos’ mansion\n\nPelosi’s mansion\n\nHillary’s mansion\n\nObama’s mansion\n\nWaters’ mansion\n\nF…',
#  "@Oprah Hi. Humble request for you to send b'day cards to 2 of my AKA Sorors turning 99 &amp; 102 on your mutual b'day/J… https://t.co/iMfXbcvheM"]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(t['text'] for t in tweets)
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:30]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                oprah	52
#                   rt	49
#                https	39
#                  don	36
#                 work	33
# mansion obama mansion	32
#               pelosi	32
#       mansion waters	32
# mansion waters mansion	32
#                obama	32
#        obama mansion	32
# obama mansion waters	32
# pelosi mansion hillary	32
#       pelosi mansion	32
#       mansion pelosi	32
#   rt the_trump_train	32
# rt the_trump_train walls	32
# the_trump_train walls don	32
# the_trump_train walls	32
#      the_trump_train	32
#                bezos	32
# mansion pelosi mansion	32
#        bezos mansion	32
# bezos mansion pelosi	32
#        mansion obama	32
#   work bezos mansion	32
#           work bezos	32
# hillary mansion obama	32
#      hillary mansion	32
#       waters mansion	32

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(t['text'] for t in tweets)
wordcloud = WordCloud(width=1200, height=800, background_color="white", 
                      stopwords=STOPWORDS).generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # First assignment, 999,999,999 points
#
# Complete the course survey!
# https://goo.gl/forms/T93f9AnIS2vGGPiA2
#
# as soon as possible
#
#
# <br><br><br>

# %%
import pandas as pd
data = pd.read_csv('survey_results.csv')
headers = ['How familiar are you with version control? (git, svn, mercurial, cvs, etc.)',
          'How familiar are you with Python?',
          ]
for h in headers:
    plt.figure()
    data[h].plot(kind='hist')
    plt.ylabel('count')
    plt.xticks(np.arange(1, 6))
    plt.title(h)
plt.show()

# %%
len(data)
# Out:
# 85

# %%
from collections import Counter
mlq = 'Have you taken a course on Machine Learning or Data Mining?'
mlclass = Counter(data[mlq])
plt.figure()
plt.title(mlq)
plt.bar([0, 1], mlclass.values(), width=.5)
plt.xticks([0, 1], mlclass.keys())
plt.ylabel('count')
plt.show()

# %%
# Why take this course question.
# Note: this wont work since I removed this column from the data in github.
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(data['Why are you taking this course?'])
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:20]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                learn	25
#                 data	24
#               social	19
#           interested	19
#             analysis	16
#             learning	15
#              machine	15
#     machine learning	15
#               course	14
#              network	11
#                 want	11
#                 like	9
#       social network	9
#     network analysis	8
#                 real	8
#          interesting	7
#           want learn	6
#         applications	6
# social network analysis	6
#               online	5

# %%
# Top words for people who have taken ML/DM
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(text, data[mlq])
print('\n'.join(words[np.argsort(clf.coef_[0])[::-1][:10]]))
# Out:
# data
# information
# understand
# love
# application
# better
# social
# online data
# field
# social network analysis
# /usr/local/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# Top words for people who have NOT taken ML/DM
print('\n'.join(words[np.argsort(clf.coef_[0])[:10]]))
# Out:
# analyse
# work
# online social
# course
# analysis
# create
# skills
# finding
# know
# learn network

# %% [markdown]
# **Any insights?**
#
# <br><br><br><br>
# https://github.com/iit-cs579/main
