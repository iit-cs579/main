# %% [markdown]
# <br><br><br><br><br>
#
#
#
# <center>
# <b><font size="+3">CS579: Online Social Network Analysis </font></b>
# <br>
# **Lecture 01**
# *[Dr. Aron Culotta](http://cs.iit.edu/~culotta)*
# *[Illinois Institute of Technology](http://iit.edu)*
#
# </center>
#
# <br><br><br><br><br><br><br>

# %% [markdown]
# <br><br><br><br><br><br><br>
#
# What is an **online social network?**
#
# <br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 50px;">
# <img width=50% src="images/fb_logo.png"/>
# </span>
#
# - 1.7B users
# - 70B pieces of content shared / day
# - 150K messages sent / minute
#
# Sources: [\[1\]](http://www.statisticbrain.com/facebook-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/twitter_logo2.png"/>
# </span>
#
# <br>
#
# - 700M users
# - 58M tweets / day
# - >200B total tweets
#
# Sources: [\[1\]](http://www.statisticbrain.com/twitter-statistics/) [\[2\]](http://expandedramblings.com/index.php/march-2013-by-the-numbers-a-few-amazing-twitter-stats/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/instagram.png"/>
# </span>
# <br>
# - 500M active users
# - 40B shared photos
# - 95M photos / day
# - 100 comments / second
#
# Sources: [\[1\]](http://www.huffingtonpost.com/brian-honigman/100-fascinating-social-me_b_2185281.html) [\[2\]](https://blog.hootsuite.com/instagram-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <span style="float: left; margin: 80px;">
# <img src="images/sina-weibo.png"/>
# </span>
# <br>
#
# - 360M active users
# - 2B daily video views
# - 100M posts / day
#
# Sources: [\[1\]](http://expandedramblings.com/index.php/weibo-user-statistics/)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### A large portion of the world's conversations are conducted in public.

# %% [markdown]
# ### Is there anything useful in this chatter?

# %% [markdown]
# ![brand](images/brand.png)
#
# [Radian6](http://www.salesforcemarketingcloud.com/blog/2012/08/social-media-insights-peekanalytics-at-work/)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![flu](images/flu.png)
#
# - [Paul & Dredze \[2011\]](http://www.cs.jhu.edu/~mdredze/publications/twitter_health_icwsm_11.pdf)
# - [Culotta \[2010\]](http://cs.iit.edu/~culotta/pubs/culotta10towards.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![gallup](images/gallup.png)
#
# [O'Connor et al. \[2010\]](http://www.cs.cmu.edu/~nasmith/papers/oconnor+balasubramanyan+routledge+smith.icwsm10.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![djia](images/djia.png)
#
# [Bollen et al. \[2010\]](http://arxiv.org/pdf/1010.3003v1.pdf)
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![crisis](images/crisis.png)
#
# [Rogstadius et al. \[2013\]](http://ufn.virtues.fi/~jakob/twitter/about.php)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ![earthquake](images/earthquake.png)
#
# [Kumar et al. \[2011\]](http://www.public.asu.edu/~mabbasi2/papers/kumar2011tweettracker.pdf)
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# **How does this** ![tweets](images/tweets.png) **become useful?**
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ###  Algorithms + Data = The Microscope of the 21st Century
#
# <table style="border: none;border-collapse: collapse;" border="0" >
# <tr><td><img src="images/tree.png" width=80%></td>
# <td>
# <ul>
# <li>Much as the microscope allowed scientists to see things they previously couldn't, now computer science provides new windows into human behavior
# <li>More human behavior is publicly observable than ever before
# <li>Supports sociology, anthropology, economics, psychology...
# <li>New algorithms are needed to sift through noise to find true patterns.
# <li>**Computational Social Science**
# </ul>
# </td></tr></table>
#
# <br><br><br><br>

# %% [markdown]
# ## This course combines...
# - Social network analysis
# - Natural language processing
# - Machine learning
#
# <br><br><br><br>
# <br><br><br><br>

# %% [markdown]
# ## Social Network Analysis
# - Study of the relationship between objects
# - Core tasks:
#   - Community detection
#   - Link prediction
#   - Spread of influence
#
#   <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Natural Language Processing
# - Algorithms allowing computers to make sense of human language
#   - text / audio
# - Core tasks:
#   - syntactic parsing
#   - entity/relation extraction
#   - sentiment classification
# - CS585
#
#   <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Machine Learning
# - Algorithms to detect patterns in data
# - Combines statistics and computer science
# - *CS584 Machine Learning*
#
# **Key tasks**
# - **Classification:** Assign a label to an object
# - **Regression:** Assign a real number to an object
# - **Clustering:** Group similar objects
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## This Course
# - Hands-on overview of social network, text analysis, machine learning
# - Survey of cutting edge research in this area
# - Technologies we'll use:
#   - Python / Jupyter notebooks
#   - Github
#   - Math
#   - Many APIs (Twitter, Facebook, LinkedIn, ...)
# - We'll use real data whenever possible
#   - Data are messy
#
# Course Website: <https://github.com/iit-cs579/main>
#
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ## Why Jupyter Notebook?
#
# - Interactive; more fun.
# - See the code behind the math.
# <br><br><br><br><br>

# %% [markdown]
# $$ f(x) = \sum_i x_i $$

# %%
def my_sum(x):
    total = 0
    for xi in x:
        total += xi
    return total

my_sum([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 45

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.arange(7)*10, [50, 75, 85, 95, 99, 99, 99], 'bo-')
plt.xlabel('hours studying', size=14)
plt.ylabel('grade', size=14)
plt.show()

# %% [markdown]
# <br><br>
# ### What are people saying about Oprah Winfrey right now?

# %%
import configparser
from TwitterAPI import TwitterAPI

def get_twitter(config_file):
    """ Read the config_file and construct an instance of TwitterAPI.
    Args:
      config_file ... A config file in ConfigParser format with Twitter credentials
    Returns:
      An instance of TwitterAPI.
    """
    config = configparser.ConfigParser()
    config.read(config_file)
    twitter = TwitterAPI(
                   config.get('twitter', 'consumer_key'),
                   config.get('twitter', 'consumer_secret'),
                   config.get('twitter', 'access_token'),
                   config.get('twitter', 'access_token_secret'))
    return twitter

twitter = get_twitter('twitter.cfg')
print('Established Twitter connection.')
# Out:
# Established Twitter connection.

# %%
request = twitter.request('search/tweets', {'q': 'oprah', 'count': 100}) 
tweets = [r for r in request]

# %%
len(tweets)
# Out:
# 100

# %%
tweets[0]
# Out:
# {'created_at': 'Mon Aug 19 16:58:50 +0000 2019',
#  'id': 1163495551632961536,
#  'id_str': '1163495551632961536',
#  'text': '@Oprah @nhannahjones @NYTmag Heart is pure, so our beloved MuLan. Help us to recast and reshoot MuLan.… https://t.co/7hjgqvm7Ex',
#  'truncated': True,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Oprah',
#     'name': 'Oprah Winfrey',
#     'id': 19397785,
#     'id_str': '19397785',
#     'indices': [0, 6]},
#    {'screen_name': 'nhannahjones',
#     'name': 'Ida Bae Wells',
#     'id': 25598396,
#     'id_str': '25598396',
#     'indices': [7, 20]},
#    {'screen_name': 'NYTmag',
#     'name': 'NYT Magazine',
#     'id': 16929600,
#     'id_str': '16929600',
#     'indices': [21, 28]}],
#   'urls': [{'url': 'https://t.co/7hjgqvm7Ex',
#     'expanded_url': 'https://twitter.com/i/web/status/1163495551632961536',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [104, 127]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': 1163220880136130560,
#  'in_reply_to_status_id_str': '1163220880136130560',
#  'in_reply_to_user_id': 19397785,
#  'in_reply_to_user_id_str': '19397785',
#  'in_reply_to_screen_name': 'Oprah',
#  'user': {'id': 830441186,
#   'id_str': '830441186',
#   'name': 'MulanMath',
#   'screen_name': 'MulanMath',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 3,
#   'listed_count': 0,
#   'created_at': 'Tue Sep 18 05:51:10 +0000 2012',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 6,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1128061584289308672/JT4-ftG2_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1128061584289308672/JT4-ftG2_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830441186/1557785757',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
tweets[0]['user']
# Out:
# {'id': 830441186,
#  'id_str': '830441186',
#  'name': 'MulanMath',
#  'screen_name': 'MulanMath',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 3,
#  'listed_count': 0,
#  'created_at': 'Tue Sep 18 05:51:10 +0000 2012',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 6,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1128061584289308672/JT4-ftG2_normal.png',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1128061584289308672/JT4-ftG2_normal.png',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/830441186/1557785757',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
[t['text'] for t in tweets]
# Out:
# ['@Oprah @nhannahjones @NYTmag Heart is pure, so our beloved MuLan. Help us to recast and reshoot MuLan.… https://t.co/7hjgqvm7Ex',
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…',
#  'RT @joelrunyon: Bill is out here on twitter showing up Oprah. https://t.co/vnEmL9AnCZ https://t.co/d51tbrrfkt',
#  '@johnpavlovitz Oprah and Barack',
#  "@MelissaLeggett4 @prayingmedic Never heard about Oprah's feet... 😫",
#  'RT @notwokieleaks: @svdate @redsteeze @jbendery If we called Rachel Dolezal “Fauxprah Winfrey,” that would not be making fun of Oprah or he…',
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…',
#  "@oprah @jimcarrey @ReeseW \n\nMonday August 19, 2019 Destin, FL\n\nRobin Fleishman is Ronald Pearlman's niece who lives… https://t.co/ISE1sXPnBM",
#  'RT @dpanabaker: “The biggest adventure you can take is to live the life of your dreams” - @Oprah',
#  'RT @OnlyInBOS: Notable Left Handed People:\n\nNeil Armstrong \nJustin Bieber\nBill Clinton\nAlbert Einstein \nEminem\nLady Gaga\nBill Gates\nJimi He…',
#  'RT @notwokieleaks: @svdate @redsteeze @jbendery If we called Rachel Dolezal “Fauxprah Winfrey,” that would not be making fun of Oprah or he…',
#  'RT @CARRIE4TRUTH: This traitor gave the Presidential Medal of Freedom to:\n\nDeniro\nDeGeneres\nHanks\nGates\nSpielberg\nStreep\nStreisand\nOprah\n\nI…',
#  'RT @joelrunyon: Bill is out here on twitter showing up Oprah. https://t.co/vnEmL9AnCZ https://t.co/d51tbrrfkt',
#  '@XOflect @NavMan_CanDo @NightShiftNews If they believe like you yes. Just look a Jay-Z , Oprah, Clarence Thomas and… https://t.co/VXM2CDGF61',
#  '@MorgKaitlin @richardaeden Well Oprah, Gayle, that crying makeup dude, and George Clooney were all too busy to defe… https://t.co/DYIXtcLApx',
#  'RT @KittyYoung_: THIS SHERYL WANTS CLOUT, distraction to people get distract to skip #LiesOfLeavingNeverland  &amp; #ChaseTheTruth  SHERYL GO T…',
#  '@Oprah @nhannahjones @NYTmag Oprah you are a fraud. Why aren’t you talking about your endorsement of the fake fraud… https://t.co/B7e7q7ydFS',
#  'RT @thesecret: "Be thankful for what you have; you\'ll end up having more. If you concentrate on what you don\'t have, you will never, ever h…',
#  '@Tiff_FitzHenry @RAZ0RFIST OPRAH thinks  she is untouchable . She just exposed herself with this crapy movie. This… https://t.co/rtdKl8W9Td',
#  'RT @joelrunyon: Bill is out here on twitter showing up Oprah. https://t.co/vnEmL9AnCZ https://t.co/d51tbrrfkt',
#  'RT @picturequotesd1: Your life is a journey of learning to love yourself first and then extending that love to others in every encounter. ~…',
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…',
#  'RT @StrongFutureWO: “I believe the choice to become a mother is the choice to become one of the greatest spiritual teachers there is.” – Op…',
#  "@GlassButterfly9 Just saw the Republican part...a joke right? I don't see a \nGOP ever marrying outside his race...maybe Oprah",
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…',
#  'RT @WneigSoul: “Turn your wounds into wisdom.” \n― Oprah Winfrey',
#  'RT @NanRaghav: @Tiff_FitzHenry Using MJ as a scapegoat for YEARS to protect the real predators of Hollywood! Lately most of the elements sl…',
#  'RT @cfemiddymusic: #Nawty video out... Please view, share and Retweet....\n@Stevydomiles @moelogo @SaharaReporters #freecuppy @DJ_TUNEZ @djT…',
#  "@MasekoValencia Shuu! I've watched one Oprah's master classes where they we're talking about this. Since then, when… https://t.co/2qXHeXcVSR",
#  "The 5 Most Influential People in my life I haven't met yet that have the pieces of what I uniquely need to be extre… https://t.co/zPn7cTXi5n",
#  "RT @JeffreyFrye: Excellent journalism here on Oprah's promotion of the #LeavingNeverland Documentary, why she is doing it now, &amp; why that i…",
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…',
#  "@oprah @jimcarrey @ReeseW \n\nMon Aug 19, 2019 Destin, FL\n\nOn Sat August 17, 2019 Destin FL my Cox Cable 35, 'CNN' @… https://t.co/b659233Nl3",
#  'RT @Justcause40: The next stage of the people behind Leaving Neverland is victim shaming because there is no logical denial that can be mad…',
#  '@realDonaldTrump I LOVE TRUMP...NO APOLOGIES @Oprah @kanyewest @mikepence',
#  '@RealMarcusJCage @NialElkim @jimmy_dore @miserablelib I see the world differently, when I was serving 70% of the po… https://t.co/VZ7w2Zkr1T',
#  '#Nawty video out... Please view, share and Retweet....\n@Stevydomiles @moelogo @SaharaReporters #freecuppy @DJ_TUNEZ… https://t.co/a1p7hJJcoo',
#  'At 30:  \n\nHarrison Ford was building kitchen cabinets. \nRobin Thicke was praying for his first hit record. \nOprah W… https://t.co/vbfK2pmaR1',
#  "RT @wishfulldreamz: @raeraefire @kabamur_taygeta maybe.... it's not as clear as Oprah, Kate Hudson and Halley Berry's six toes! https://t.c…",
#  'RT @NoursThoughts: I started watching Oprah’s interview last night with the central park five, and I got this feeling again. It make me sic…',
#  'RT @zaynissoft1: "Stop the ego and break the fences\nAnd when they say build a wall you say for whose house? \nWho should I call? \nI do not p…',
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…',
#  'RT @paulsperry_: Marianne Williamson taught classes from a book "A Course in Miracles" written by a nutty shrink who claimed she was dictat…']

# %%
from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(t['text'] for t in tweets)
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:30]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                oprah	66
#                   rt	55
#                https	40
#          paulsperry_	14
#              classes	14
#     miracles written	13
#        written nutty	13
#             marianne	13
#  marianne williamson	13
# marianne williamson taught	13
#             miracles	13
#  taught classes book	13
#       taught classes	13
#               taught	13
# written nutty shrink	13
# miracles written nutty	13
#         nutty shrink	13
# nutty shrink claimed	13
# shrink claimed dictat	13
#       shrink claimed	13
#               shrink	13
# paulsperry_ marianne	13
# paulsperry_ marianne williamson	13
# rt paulsperry_ marianne	13
#                nutty	13
#       rt paulsperry_	13
#              claimed	13
#               dictat	13
# williamson taught classes	13
#    williamson taught	13

# %%
from wordcloud import WordCloud, STOPWORDS

text = ' '.join(t['text'] for t in tweets)
wordcloud = WordCloud(width=1200, height=800, background_color="white", 
                      stopwords=STOPWORDS).generate(text)
plt.figure(figsize=(12, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # First assignment, 999,999,999 points
#
# Complete the course survey!
# https://forms.gle/ADnLtUPW3CskXRzX7
#
# as soon as possible
#
#
# <br><br><br>

# %%
import pandas as pd
data = pd.read_csv('survey_results.csv')
headers = ['How familiar are you with version control? (git, svn, mercurial, cvs, etc.)',
          'How familiar are you with Python?',
          ]
for h in headers:
    plt.figure()
    data[h].plot(kind='hist')
    plt.ylabel('count')
    plt.xticks(np.arange(1, 6))
    plt.title(h)
plt.show()

# %%
len(data)
# Out:
# 85

# %%
from collections import Counter
mlq = 'Have you taken a course on Machine Learning or Data Mining?'
mlclass = Counter(data[mlq])
plt.figure()
plt.title(mlq)
plt.bar([0, 1], mlclass.values(), width=.5)
plt.xticks([0, 1], mlclass.keys())
plt.ylabel('count')
plt.show()

# %%
# Why take this course question.
# Note: this wont work since I removed this column from the data in github.
from sklearn.feature_extraction.text import CountVectorizer

vec = CountVectorizer(binary=True, stop_words='english', ngram_range=(1,3), min_df=2)
text = vec.fit_transform(data['Why are you taking this course?'])
counts = text.sum(axis=0).getA1()
words = np.array(vec.get_feature_names())

for idx in np.argsort(counts)[::-1][:20]:
    print('%20s\t%d' % (words[idx], counts[idx]))
# Out:
#                learn	25
#                 data	24
#               social	19
#           interested	19
#             analysis	16
#             learning	15
#              machine	15
#     machine learning	15
#               course	14
#              network	11
#                 want	11
#                 like	9
#       social network	9
#     network analysis	8
#                 real	8
#          interesting	7
#           want learn	6
#         applications	6
# social network analysis	6
#               online	5

# %%
# Top words for people who have taken ML/DM
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(solver='lbfgs')
clf.fit(text, data[mlq])
print('\n'.join(words[np.argsort(clf.coef_[0])[::-1][:10]]))
# Out:
# data
# information
# understand
# love
# application
# better
# online data
# social
# field
# social network analysis

# %%
# Top words for people who have NOT taken ML/DM
print('\n'.join(words[np.argsort(clf.coef_[0])[:10]]))
# Out:
# analyse
# work
# online social
# course
# analysis
# create
# finding
# skills
# know
# learn network

# %% [markdown]
# **Any insights?**
#
# <br><br><br><br>
# https://github.com/iit-cs579/main

# %%
from IPython.core.display import HTML
HTML(open('../custom.css').read())
# Out:
# <link href="https://fonts.googleapis.com/css?family=Droid+Sans+Mono" rel="stylesheet" type='text/css'>
#
# <link href="https://fonts.googleapis.com/css?family=Exo+2" rel="stylesheet" type='text/css'>
#
# <link href="https://fonts.googleapis.com/css?family=Lora" rel="stylesheet" type='text/css'>
#
# <link href="https://fonts.googleapis.com/css?family=Fira+Mono" rel="stylesheet" type='text/css'>
#
# <style>
#
# div#site {
#     height: 100% !important;
# }
#
# strong {
#   font-weight: 900 !important;
# }
#
# .container { width:90% !important; }
#
#
# div#notebook {
#  font-family: "Exo_2", sans-serif;
#  font-size: 20pt;
#  line-height: 170%;
#  color: #303030;
# }
# body,
# div.body {
#  font-family: "Exo_2", sans-serif;
#  font-size: 20pt;
#  color: #303030;
#  background-color: #ffffff;
#  background: #ffffff;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #ffffff;
#  background: #ffffff;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: "Exo_2", sans-serif;
#  color: #303030;
# }
# a:hover,
# a:focus {
#  color: #2f2f2f;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 20pt;
#  color: #2f2f2f;
#  background-color: #ffffff;
# }
# div#cluster_list_header.row.list_header,
# div#running .row.list_header {
#  font-size: 20pt;
#  color: #303030;
#  background: #eeeeee;
#  background-color: #eeeeee;
#  border-bottom: 2px solid rgba(180,180,180,.30);
# }
# div#cluster_list > div.list_item.row,
# div#cluster_list > div.list_item.row:hover {
#  background: #fafafa;
#  background-color: #fafafa;
# }
# div#clusters.tab-pane.active {
#  font-size: 12.0pt;
#  padding: 4px 0 4px 0;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #303030;
#  padding: 8px 8px;
#  background: #eeeeee;
#  background-color: #eeeeee;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #303030;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #303030;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #fafafa;
#  background-color: #fafafa;
#  padding: 2px;
#  border-bottom: 2px solid rgba(180,180,180,.30);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #fafafa;
#  background-color: #fafafa;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# div.running_list_info.toolbar_info {
#  font-size: 12.0pt;
#  padding: 4px 0 4px 0;
#  height: inherit;
#  line-height: inherit;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #ff7823;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# #project_name {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  margin-bottom: -20px;
#  text-align: -webkit-auto;
#  vertical-align: text-top;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: "Exo_2", sans-serif;
#  font-size: 12.0pt;
# }
# .toolbar_info {
#  font-family: "Exo_2", sans-serif;
#  font-size: 12.0pt;
#  color: #303030;
#  text-shadow: none;
#  border: none;
#  height: inherit;
#  line-height: inherit;
# }
# .list_container {
#  font-size: 12.0pt;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(180,180,180,.14);
#  font-size: 12.0pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-left: 0px;
# }
# .list_header > div input,
# .list_item > div input {
#  top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 12.0pt;
# }
# .item_icon {
#  font-size: 12.0pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: auto;
#  width: 20%;
#  margin: 6px 0 0;
#  margin-top: 1px;
# }
# #button-select-all {
#  height: auto;
#  font-size: 12.0pt;
#  padding: 5px;
#  min-width: 65px;
#  z-index: 0;
# }
# button#tree-selector-btn {
#  height: auto;
#  font-size: 12.0pt;
#  padding: 5px;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 5px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin: 6px 0 0;
#  margin-top: 1px;
#  line-height: normal;
# }
# .list_container a {
#  font-size: 17px;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #2f2f2f;
# }
# div.list_item:hover {
#  background-color: #fafafa;
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
# }
# ul#tabs a {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  font-weight: normal;
#  font-style: normal;
#  border-color: transparent;
#  text-shadow: none !important;
# }
# .nav-tabs {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  font-weight: normal;
#  font-style: normal;
#  background: #ffffff;
#  text-shadow: none !important;
#  border-color: transparent;
#  border-bottom-color: rgba(180,180,180,.30);
# }
# .nav-tabs > li > a:hover {
#  color: #2f2f2f;
#  background-color: rgba(180,180,180,.14);
# }
# .nav-tabs > li > a:active,
# .nav-tabs > li > a:focus,
# .nav-tabs > li.active > a,
# .nav-tabs > li.active > a:focus,
# .nav-tabs > li.active > a:hover,
# .nav-tabs > li.active > a,
# .nav-tabs > li.active > a:hover,
# .nav-tabs > li.active > a:focus {
#  color: #1c1c1c;
#  background-color: #eeeeee;
#  border: 1px solid transparent;
#  border-bottom-color: transparent;
#  cursor: default;
# }
# .nav > li > a:hover,
# .nav > li > a:focus {
#  text-decoration: none;
#  background-color: rgba(180,180,180,.14);
# }
# .nav > li.disabled > a,
# .nav > li.disabled > a:hover {
#  color: #aaaaaa;
# }
# div#notebook {
#  font-family: "Exo_2", sans-serif;
#  font-size: 20pt;
#  padding-top: 4px;
# }
# .notebook_app {
#  background-color: #ffffff;
# }
# #notebook-container {
#  padding: 13px;
#  background-color: #ffffff;
#  min-height: 0px;
#  box-shadow: none;
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
# }
# div#ipython-main-app.container {
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
#  margin-right: auto;
#  margin-left: auto;
# }
# .container {
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
# }
# .notebook_app #header {
#  box-shadow: none !important;
#  background-color: #ffffff;
#  border-bottom: 2px solid rgba(180,180,180,.14);
# }
# #header {
#  font-family: "Exo_2", sans-serif;
#  font-size: 22pt;
#  box-shadow: none;
#  background-color: #ffffff;
# }
# #header .header-bar {
#  background: #ffffff;
#  background-color: #ffffff;
# }
# body > #header .header-bar {
#  width: 100%;
#  background: #ffffff;
# }
# #menubar {
#  background-color: #ffffff;
# }
# #menubar .navbar,
# .navbar-default {
#  background-color: #ffffff;
#  margin-bottom: 0px;
#  margin-top: 5px;
# }
# .navbar {
#  border: none;
# }
# div.navbar-text,
# .navbar-text {
#  margin-top: 6px !important;
#  margin-bottom: 0px;
# }
# .navbar-default {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  background-color: #ffffff;
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
#  padding-bottom: 0px;
# }
# .navbar-default .navbar-nav > li > a {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  color: #303030;
#  display: block;
#  line-height: 1.5em;
#  padding-top: 9px;
#  padding-bottom: 6px;
# }
# .navbar-default .navbar-nav > li > a:hover,
# .navbar-default .navbar-nav > li > a:focus {
#  color: #2f2f2f;
#  background-color: rgba(180,180,180,.14);
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
# }
# .navbar-default .navbar-nav > .open > a,
# .navbar-default .navbar-nav > .open > a:hover,
# .navbar-default .navbar-nav > .open > a:focus {
#  color: #1c1c1c;
#  background-color: rgba(180,180,180,.14);
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
# }
# .edit_mode .modal_indicator:before {
#  font-size: 15pt;
#  color: #2c85f7;
#  content: "\f040";
#  padding-top: 5px;
#  padding-bottom: 0px;
#  vertical-align: bottom;
# }
# .command_mode .modal_indicator:before {
#  font-size: 17pt;
#  color: #2c85f7;
#  content: "\f1f9";
#  padding-top: 5px;
#  padding-bottom: 0px;
#  vertical-align: bottom;
# }
# .item_icon {
#  color: #126dce;
# }
# .item_buttons .kernel-name {
#  font-size: 13pt;
#  color:
